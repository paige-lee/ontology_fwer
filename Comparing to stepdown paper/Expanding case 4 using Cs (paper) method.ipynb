# %% [markdown]
# # 1. Setup

# %%
import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd
import re
from glob import glob
import os

# %%
# Import the functions

from functions_py_file import *

# %%
# Read in data

adjacency_matrix = pd.read_csv("adjacency_matrix2.csv", header=0, index_col=0)

multilevel = pd.read_csv("multilevel2.csv", header=0, index_col=0)

# %%
# Clean the adjacency matrix
adjacency_matrix = clean_adjacency_mat(adjacency_matrix)

# Clean the multilevel lookup table
multilevel = clean_multilevel(multilevel, adjacency_matrix)

# %%
# Create the subset adjacency matrix

subset_leaf_list = ["Amyg_L_73_1", "Hippo_L_75_1"]
subset = subset_matrix_creator(subset_leaf_list, adjacency_matrix, multilevel)

# %%
# Create the descendants matrix
descendants = adjacency_descendants(subset, N=20, mu=3.0)

# Create the ancestors matrix
ancestors = adjacency_ancestors(subset, N=20, mu=3.0)

# %% [markdown]
# # 2. Generating data

# %%
# Generate simulated data
# Case 4, 100 repeats, mu 2

np.random.seed(5)
generate_simulated_data(filename="test4_data.npz", subset=subset, case=4, n_repeats=100, N=20, mu=2.0)

# %% [markdown]
# # 3. Cs (paper) method for permutation testing and stepdown procedure

# %%
# Modified permutation testing function

def permutation_testing2(filename_old, filename_new, subset, ignore, n_repeats, nperm, N, mu, niter, clip, initial_prob):
    ''' Function that conducts permutation testing
    
    This function conducts permutation testing using the generated data
    
    Parameters
    ----------
    filename_old: string
        The pattern of the filenames of the generated data; example: "test1_data_repeat_*"
    
    filename_new: string
        The user-specified filename pattern for the permutation testing results (choose a different name from 
        filename_old, i.e. say "results" instead of "data" if you don't want generated data to get overwritten 
        by permutation testing results); example: "results.npz"
    
    subset: pandas.DataFrame
        The subset adjacency matrix
    
    ignore: list
        A list of integers to ignore (structures that were rejected in previous function calls); 
        or it could be any empty list to not ignore anything
    
    n_repeats: int
        The number of repeats. We generated a random dataset with the same parameters but `n_repeats` 
        different realizations of the random variables. `n_repeats` must be the same value as `n_repeats`
        when we generated data earlier. n_repeats should be 1 in practice for external users, but in our case, 
        since we simulated a lot of data, n_repeats is greater than 1.
    
    nperm: int
        The number of permutations for permutation testing 
    
    N: int
        The number of samples. N must be the same value as N from generating data earlier.
    
    mu: float
        The difference in means (generally unknown). mu should be the same value as mu from generating data
        earlier in order to get meaningful results. But, mu doesn't have to be the same if you don't want to
        make it the same.
    
    niter: int
        The number of iterations of the EM algorithm
    
    clip: float
        Number that clips probabilities away from 0 or 1
    
    initial_prob: float
        The intial probability
    
    Returns 
    ----------
    npz file (written to disk, not explicitly returned)
        The 1st array contains p-values, 2nd array contains the names of the structures in the subset, 3rd 
        array contains the posterior probabilities, and 4th array contains the information from the prior 3 
        arrays saved in 1 string per structure.
    
    '''
    
    M = subset.shape[0] # Number of total unique structures
    S = np.array(subset, dtype = bool)
    names_subset = subset.columns # List of the 8 structures' names
    Descendants = adjacency_descendants(subset, N=N, mu=mu)
    Descendants_and_self = np.logical_or(Descendants, np.eye(M))
    
    basename, extension = os.path.splitext(filename_new)
    filename_old = glob(filename_old)
    filename_old = sorted(filename_old)
    
    for j in range(n_repeats):
        
        # Load the generated data for each repeat
        data = np.load(filename_old[j])
        X = data["X"]
        Z = data["Z"]
        G = data["G"]
        
        outputs = [] # Empty list for each iteration
        
        ### PARAMETER ESTIMATION ###
    
        P_subset = np.ones(M) * 0.5 # Array of 8 copies of 0.5
        Q = Q_from_P(P_subset, S)

        P0 = np.ones(M) * initial_prob
        P_subset = estimate_P(X[G], mu, S, Descendants_and_self, draw=0, P0=P0, niter=niter, names=names_subset, clip=clip)
        # Set draw = 0 to prevent drawing the graphs
        P_subset[ignore] = -1 # Set the ignored structures to -1 so they'll never be the maximum 
        ind = np.argsort(P_subset[::-1])[::-1][0] # Index of the maximum value of P_subset (among the non-excluded structures)
        ind = len(P_subset) - ind - 1 # Flips the order of contents in P_subset so they apply to the unflipped P_subset
        
        ### GENERATING PERMUTED DATA ###
    
        Ps = []
        np.random.seed(5)
        for n in range(nperm):
            Xp = X[np.random.permutation(N)[G]]
            P_ = estimate_P(Xp,mu,S,Descendants_and_self,draw=0,niter=niter,P0=P0)
            P_ = [element for i, element in enumerate(P_) if i not in ignore] # Remove ignored structures from P_
            Ps.append(P_) # Append the subset of P_
        
        Ps = np.array(Ps)
        Ps_sort = np.max(Ps, axis = 1) # Maximum value of Ps
        
        ### PERMUTATION TESTING ###
    
        pval = np.zeros_like(P_subset)
        alpha = 0.05
        
        pval_list = [] # Empty list to be filled
        names_list = [] # Empty list to be filled
        posterior_list = [] # Empty list to be filled
        
        pval = np.mean(Ps_sort >= P_subset[ind])
        outputs.append(f"{names_subset[ind]}, P[Z=1|X]={P_subset[ind]}, p={pval}") 
        pval_list.append(pval)
        # Every structure that gets rejected gets an entry
        names_list.append(names_subset[ind])
        posterior_list.append(P_subset[ind])
                    
        
        ### SORT THE POSTERIOR VALUES ###
        
        # Use the subset adjacency matrix to create a dictionary
        columns = np.array(subset.columns)
        dictionary = dict(enumerate(columns.flatten(), 1))
        dictionary = dict((value, key) for key, value in dictionary.items()) # Swap the keys and values
        outputs = sorting_function(outputs, dictionary)
        
        ### SAVE DATA ### 
        
        filename_new_this_repeat = basename + f'_repeat_{j:06d}' + extension
        np.savez(filename_new_this_repeat, pval = pval_list, names = names_list, posterior = posterior_list, strings = outputs)
        
    ### OUTPUTS ###
    return pval, ind, np.quantile(Ps_sort, 0.95), names_list

# %%
# IMPLEMENT THE STEPDOWN PROCEDURE (case 4)

ignore_list = [] # Initialize ignore_list as an empty list
critical_values = [] # Initialize critical_values as an empty list
p_values = [] # Initialize p_values as an empty list
M = subset.shape[0] # Number of total unique structures

while True: # Loop to call the function multiple times
    results = permutation_testing2(filename_old="test4_data_repeat_*", filename_new = "test4_results.npz", ignore = ignore_list, subset=subset, n_repeats=100, nperm=100, N=20, mu=2.0, niter=5, initial_prob = 0.5, clip=0.001)
    print("Structure: ", results[3])
    if ((results[0] < 0.05) or True): # If the output p-value is < 0.05...
        ignore_list.append(results[1]) # Add the maximum structure to the ignore list
        critical_values.append(results[2])
        p_values.append(results[0])
    else:
        # if we fail to reject one hypothesis, we stop testing 
        # but, for our study we will still want all M structures, so above we say "or True"
        break
    if (len(ignore_list) == M): # Break once the ignore list is filled with every structure
        break
# Out:
# Structure:  ['Everything']
# Structure:  ['Telencephalon_L_501_5']
# Structure:  ['CerebralCortex_L_482_4']
# Structure:  ['Limbic_L_434_3']
# Structure:  ['Amyg_L_336_2']
# Structure:  ['Amyg_L_73_1']
# Structure:  ['Hippo_L_338_2']
# Structure:  ['Hippo_L_75_1']

# %%
p_values
# Out:
# [0.0, 0.0, 0.0, 0.0, 0.06, 0.06, 0.05, 0.05]

# %% [markdown]
# # 4. How often do we detect nothing at child level and something at parent level?

# %%
# Viewing the saved results

test4_filenames = glob("test4_results_repeat_*")
test4_filenames = sorted(test4_filenames)

for i in range(0, len(test4_filenames)):
    # Assign the file to an object called "test," which is a dictionary object
    test = np.load(test4_filenames[i])
    print("\033[1m" + test4_filenames[i] + "\033[0m") 

    # Print the values corresponding to each key
    print("\033[1m" + "p-values:" + "\033[0m")
    print(test["pval"])
    
    print("\033[1m" + "names:" + "\033[0m")
    print(test["names"])
    
    print("\033[1m" + "posterior:" + "\033[0m")
    print(test["posterior"])
    
    print("\033[1m" + "strings:" + "\033[0m")
    print(test["strings"])
    print("\n")
# Out:
# test4_results_repeat_000000.npz
# p-values:
# [0.04]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.4539879]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.45398789622528735, p=0.04']
#
#
# test4_results_repeat_000001.npz
# p-values:
# [0.44]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.2738127]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.2738126961097244, p=0.44']
#
#
# test4_results_repeat_000002.npz
# p-values:
# [0.04]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.69611634]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.696116338936419, p=0.04']
#
#
# test4_results_repeat_000003.npz
# p-values:
# [0.07]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.3894126]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.3894126008270704, p=0.07']
#
#
# test4_results_repeat_000004.npz
# p-values:
# [0.01]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.36347559]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.36347559103723187, p=0.01']
#
#
# test4_results_repeat_000005.npz
# p-values:
# [0.06]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.50341991]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.5034199097684798, p=0.06']
#
#
# test4_results_repeat_000006.npz
# p-values:
# [0.02]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.73031117]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.7303111729745068, p=0.02']
#
#
# test4_results_repeat_000007.npz
# p-values:
# [0.04]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.5502619]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.5502619023296714, p=0.04']
#
#
# test4_results_repeat_000008.npz
# p-values:
# [0.1]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.51956683]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.5195668258505333, p=0.1']
#
#
# test4_results_repeat_000009.npz
# p-values:
# [0.34]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.22388044]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.22388044488275832, p=0.34']
#
#
# test4_results_repeat_000010.npz
# p-values:
# [0.06]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.57159975]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.5715997455025861, p=0.06']
#
#
# test4_results_repeat_000011.npz
# p-values:
# [0.]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.9012791]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.9012791034184175, p=0.0']
#
#
# test4_results_repeat_000012.npz
# p-values:
# [0.1]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.28409571]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.28409570880002233, p=0.1']
#
#
# test4_results_repeat_000013.npz
# p-values:
# [0.02]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.68508638]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.6850863767775509, p=0.02']
#
#
# test4_results_repeat_000014.npz
# p-values:
# [0.13]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.23556504]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.23556504425295488, p=0.13']
#
#
# test4_results_repeat_000015.npz
# p-values:
# [0.]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.75332577]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.7533257689399372, p=0.0']
#
#
# test4_results_repeat_000016.npz
# p-values:
# [0.48]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.36289176]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.3628917579773508, p=0.48']
#
#
# test4_results_repeat_000017.npz
# p-values:
# [0.]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.47943935]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.47943934795550874, p=0.0']
#
#
# test4_results_repeat_000018.npz
# p-values:
# [0.06]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.48149877]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.48149876786436385, p=0.06']
#
#
# test4_results_repeat_000019.npz
# p-values:
# [0.05]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.71010006]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.7101000577645721, p=0.05']
#
#
# test4_results_repeat_000020.npz
# p-values:
# [0.29]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.48233819]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.48233818692344776, p=0.29']
#
#
# test4_results_repeat_000021.npz
# p-values:
# [0.27]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.14575998]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.1457599798988693, p=0.27']
#
#
# test4_results_repeat_000022.npz
# p-values:
# [0.04]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.4208248]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.4208247959953083, p=0.04']
#
#
# test4_results_repeat_000023.npz
# p-values:
# [0.15]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.27902577]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.2790257747273383, p=0.15']
#
#
# test4_results_repeat_000024.npz
# p-values:
# [0.27]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.5523899]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.5523898977528547, p=0.27']
#
#
# test4_results_repeat_000025.npz
# p-values:
# [0.01]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.39447496]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.39447495545222894, p=0.01']
#
#
# test4_results_repeat_000026.npz
# p-values:
# [0.27]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.56920698]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.5692069774672531, p=0.27']
#
#
# test4_results_repeat_000027.npz
# p-values:
# [0.14]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.47920051]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.47920051218242676, p=0.14']
#
#
# test4_results_repeat_000028.npz
# p-values:
# [0.49]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.11326657]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.11326657200876115, p=0.49']
#
#
# test4_results_repeat_000029.npz
# p-values:
# [0.]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.44500295]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.4450029481605277, p=0.0']
#
#
# test4_results_repeat_000030.npz
# p-values:
# [0.07]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.55839329]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.5583932924681406, p=0.07']
#
#
# test4_results_repeat_000031.npz
# p-values:
# [0.]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.60968728]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.60968727667546, p=0.0']
#
#
# test4_results_repeat_000032.npz
# p-values:
# [0.53]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.08475744]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.08475743549927581, p=0.53']
#
#
# test4_results_repeat_000033.npz
# p-values:
# [0.11]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.25344705]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.2534470534945243, p=0.11']
#
#
# test4_results_repeat_000034.npz
# p-values:
# [0.]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.80774961]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.8077496054347263, p=0.0']
#
#
# test4_results_repeat_000035.npz
# p-values:
# [0.03]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.54087948]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.5408794798655513, p=0.03']
#
#
# test4_results_repeat_000036.npz
# p-values:
# [0.22]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.17565457]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.1756545728364595, p=0.22']
#
#
# test4_results_repeat_000037.npz
# p-values:
# [0.25]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.51403023]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.5140302292187179, p=0.25']
#
#
# test4_results_repeat_000038.npz
# p-values:
# [0.03]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.68281033]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.682810326130654, p=0.03']
#
#
# test4_results_repeat_000039.npz
# p-values:
# [0.]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.78210351]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.7821035090872703, p=0.0']
#
#
# test4_results_repeat_000040.npz
# p-values:
# [0.04]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.43283397]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.4328339741773683, p=0.04']
#
#
# test4_results_repeat_000041.npz
# p-values:
# [0.01]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.82543318]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.8254331770189405, p=0.01']
#
#
# test4_results_repeat_000042.npz
# p-values:
# [0.18]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.16565229]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.16565229219535266, p=0.18']
#
#
# test4_results_repeat_000043.npz
# p-values:
# [0.23]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.41276218]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.41276218065972586, p=0.23']
#
#
# test4_results_repeat_000044.npz
# p-values:
# [0.08]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.17481321]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.17481321259709962, p=0.08']
#
#
# test4_results_repeat_000045.npz
# p-values:
# [0.01]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.51798443]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.5179844335422953, p=0.01']
#
#
# test4_results_repeat_000046.npz
# p-values:
# [0.12]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.38751947]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.38751946875172816, p=0.12']
#
#
# test4_results_repeat_000047.npz
# p-values:
# [0.01]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.47547855]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.47547855320164106, p=0.01']
#
#
# test4_results_repeat_000048.npz
# p-values:
# [0.01]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.35393755]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.35393754979601366, p=0.01']
#
#
# test4_results_repeat_000049.npz
# p-values:
# [0.11]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.15544445]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.15544445199946927, p=0.11']
#
#
# test4_results_repeat_000050.npz
# p-values:
# [0.]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.68906431]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.6890643108558013, p=0.0']
#
#
# test4_results_repeat_000051.npz
# p-values:
# [0.3]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.29541703]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.29541703428533855, p=0.3']
#
#
# test4_results_repeat_000052.npz
# p-values:
# [0.07]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.42967078]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.429670776177068, p=0.07']
#
#
# test4_results_repeat_000053.npz
# p-values:
# [0.27]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.1585435]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.1585435024208431, p=0.27']
#
#
# test4_results_repeat_000054.npz
# p-values:
# [0.02]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.4963783]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.4963783022846697, p=0.02']
#
#
# test4_results_repeat_000055.npz
# p-values:
# [0.]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.99723377]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.9972337729503241, p=0.0']
#
#
# test4_results_repeat_000056.npz
# p-values:
# [0.]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.5999852]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.5999851985892026, p=0.0']
#
#
# test4_results_repeat_000057.npz
# p-values:
# [0.03]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.49196574]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.491965738272942, p=0.03']
#
#
# test4_results_repeat_000058.npz
# p-values:
# [0.03]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.66329406]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.6632940621621792, p=0.03']
#
#
# test4_results_repeat_000059.npz
# p-values:
# [0.01]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.58904981]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.5890498121041754, p=0.01']
#
#
# test4_results_repeat_000060.npz
# p-values:
# [0.01]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.65860765]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.658607649723123, p=0.01']
#
#
# test4_results_repeat_000061.npz
# p-values:
# [0.]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.61581151]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.6158115128469277, p=0.0']
#
#
# test4_results_repeat_000062.npz
# p-values:
# [0.36]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.41677405]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.41677404767498105, p=0.36']
#
#
# test4_results_repeat_000063.npz
# p-values:
# [0.]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.38562291]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.3856229074738099, p=0.0']
#
#
# test4_results_repeat_000064.npz
# p-values:
# [0.31]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.455456]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.45545600015773635, p=0.31']
#
#
# test4_results_repeat_000065.npz
# p-values:
# [0.1]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.33818904]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.3381890363781353, p=0.1']
#
#
# test4_results_repeat_000066.npz
# p-values:
# [0.78]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.02045501]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.020455012463390352, p=0.78']
#
#
# test4_results_repeat_000067.npz
# p-values:
# [0.13]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.22199329]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.22199328604352178, p=0.13']
#
#
# test4_results_repeat_000068.npz
# p-values:
# [0.19]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.51073833]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.5107383345246442, p=0.19']
#
#
# test4_results_repeat_000069.npz
# p-values:
# [0.02]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.46076392]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.46076392026869284, p=0.02']
#
#
# test4_results_repeat_000070.npz
# p-values:
# [0.1]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.6473066]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.6473066001885589, p=0.1']
#
#
# test4_results_repeat_000071.npz
# p-values:
# [0.]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.65687588]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.6568758766947339, p=0.0']
#
#
# test4_results_repeat_000072.npz
# p-values:
# [0.31]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.18073211]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.18073211132079595, p=0.31']
#
#
# test4_results_repeat_000073.npz
# p-values:
# [0.01]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.47305644]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.4730564367257596, p=0.01']
#
#
# test4_results_repeat_000074.npz
# p-values:
# [0.03]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.4907905]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.4907904976170128, p=0.03']
#
#
# test4_results_repeat_000075.npz
# p-values:
# [0.02]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.47765169]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.47765168778212885, p=0.02']
#
#
# test4_results_repeat_000076.npz
# p-values:
# [0.07]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.6766744]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.6766744004780711, p=0.07']
#
#
# test4_results_repeat_000077.npz
# p-values:
# [0.12]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.28379697]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.28379696896671774, p=0.12']
#
#
# test4_results_repeat_000078.npz
# p-values:
# [0.1]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.60253808]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.6025380830482618, p=0.1']
#
#
# test4_results_repeat_000079.npz
# p-values:
# [0.]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.66421143]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.6642114280803626, p=0.0']
#
#
# test4_results_repeat_000080.npz
# p-values:
# [0.07]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.35126347]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.3512634662591114, p=0.07']
#
#
# test4_results_repeat_000081.npz
# p-values:
# [0.]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.79377947]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.7937794669434651, p=0.0']
#
#
# test4_results_repeat_000082.npz
# p-values:
# [0.05]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.43944397]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.4394439705617238, p=0.05']
#
#
# test4_results_repeat_000083.npz
# p-values:
# [0.06]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.56255536]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.5625553587698155, p=0.06']
#
#
# test4_results_repeat_000084.npz
# p-values:
# [0.04]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.75139758]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.751397581252836, p=0.04']
#
#
# test4_results_repeat_000085.npz
# p-values:
# [0.]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.50272748]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.5027274774484838, p=0.0']
#
#
# test4_results_repeat_000086.npz
# p-values:
# [0.]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.66095445]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.6609544548500274, p=0.0']
#
#
# test4_results_repeat_000087.npz
# p-values:
# [0.15]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.38952813]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.38952813005981424, p=0.15']
#
#
# test4_results_repeat_000088.npz
# p-values:
# [0.]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.62724817]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.6272481743340241, p=0.0']
#
#
# test4_results_repeat_000089.npz
# p-values:
# [0.07]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.58165069]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.5816506940478229, p=0.07']
#
#
# test4_results_repeat_000090.npz
# p-values:
# [0.14]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.20569205]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.20569205154026493, p=0.14']
#
#
# test4_results_repeat_000091.npz
# p-values:
# [0.06]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.19685122]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.19685122281378722, p=0.06']
#
#
# test4_results_repeat_000092.npz
# p-values:
# [0.05]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.85702276]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.8570227645452443, p=0.05']
#
#
# test4_results_repeat_000093.npz
# p-values:
# [0.33]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.20714159]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.2071415918656573, p=0.33']
# test4_results_repeat_000094.npz
# p-values:
# [0.09]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.17303211]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.17303210832139576, p=0.09']
#
#
# test4_results_repeat_000095.npz
# p-values:
# [0.]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.96570268]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.965702678402009, p=0.0']
#
#
# test4_results_repeat_000096.npz
# p-values:
# [0.]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.5874723]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.5874722984189769, p=0.0']
#
#
# test4_results_repeat_000097.npz
# p-values:
# [0.01]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.6831758]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.6831757998437109, p=0.01']
#
#
# test4_results_repeat_000098.npz
# p-values:
# [0.03]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.55309553]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.5530955271463276, p=0.03']
#
#
# test4_results_repeat_000099.npz
# p-values:
# [0.05]
# names:
# ['Hippo_L_75_1']
# posterior:
# [0.57363865]
# strings:
# ['Hippo_L_75_1, P[Z=1|X]=0.5736386514849232, p=0.05']
